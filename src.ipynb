# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
weight = np.random.normal(loc=70, scale=5, size=500)
#height = np.random.normal(loc=170, scale=7.5, size=500)
height = (-2*weight) + 5 + np.random.normal(loc=20, scale=8, size=500)
data=pd.DataFrame(data={'Weight (Kgs)': weight, 'Height (cms)': height})

# %%
data
# Out:
#      Weight (Kgs)  Height (cms)
# 0       67.401322   -116.571420
# 1       75.142338   -131.198134
# 2       77.060555   -134.834753
# 3       63.787572   -103.820434
# 4       71.037667   -100.047072
# ..            ...           ...
# 495     61.892692    -81.313501
# 496     66.653385   -106.380044
# 497     63.413856    -98.298069
# 498     70.001255    -99.916081
# 499     71.978056   -115.666357
#
# [500 rows x 2 columns]

# %%
data.mean(axis=0)
# Out:
# Weight (Kgs)     70.125561
# Height (cms)   -114.817740
# dtype: float64

# %%
plt.scatter(data['Weight (Kgs)'], data['Height (cms)'])
plt.xlabel('Weight (Kgs)')
plt.ylabel('Height (cms)')
plt.title('Scatter plot of Weight vs Height')
plt.show()
