# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
weight = np.random.normal(loc=70, scale=5, size=500)
#height = np.random.normal(loc=170, scale=7.5, size=500)
height = (2*weight) + 5
data=pd.DataFrame(data={'Weight (Kgs)': weight, 'Height (cms)': height})

# %%
data
# Out:
#      Weight (Kgs)  Height (cms)
# 0       65.809169    136.618339
# 1       76.942469    158.884939
# 2       76.868660    158.737321
# 3       60.226557    125.453114
# 4       70.759267    146.518535
# ..            ...           ...
# 495     71.896636    148.793271
# 496     73.251546    151.503092
# 497     69.748486    144.496972
# 498     68.892719    142.785437
# 499     64.139734    133.279469
#
# [500 rows x 2 columns]

# %%
data.mean(axis=0)
# Out:
# Weight (Kgs)     69.775533
# Height (cms)    144.551066
# dtype: float64

# %%
plt.scatter(data['Weight (Kgs)'], data['Height (cms)'])
plt.xlabel('Weight (Kgs)')
plt.ylabel('Height (cms)')
plt.title('Scatter plot of Weight vs Height')
plt.show()
