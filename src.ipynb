# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
weight = np.random.normal(loc=70, scale=5, size=500)
#height = np.random.normal(loc=170, scale=7.5, size=500)
height = (-2*weight) + 5 + np.random.normal(loc=20, scale=5, size=500)
data=pd.DataFrame(data={'Weight (Kgs)': weight, 'Height (cms)': height})

# %%
data
# Out:
#      Weight (Kgs)  Height (cms)
# 0       70.500085   -117.174516
# 1       71.373298   -124.057312
# 2       77.730851   -131.112481
# 3       75.332464   -126.895882
# 4       74.117785   -116.197191
# ..            ...           ...
# 495     78.616504   -130.801500
# 496     76.532458   -137.311054
# 497     67.687081   -117.651529
# 498     70.526933   -111.418415
# 499     73.732435   -124.153122
#
# [500 rows x 2 columns]

# %%
data.mean(axis=0)
# Out:
# Weight (Kgs)     70.107324
# Height (cms)   -115.120656
# dtype: float64

# %%
plt.scatter(data['Weight (Kgs)'], data['Height (cms)'])
plt.xlabel('Weight (Kgs)')
plt.ylabel('Height (cms)')
plt.title('Scatter plot of Weight vs Height')
plt.show()
